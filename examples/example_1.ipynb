# %%
import pyAERO

# %%
pyAERO.GetDataAEROET('Sao_Paulo','2002-02-01','2005-02-01','AOD10',temporal_type=True)

# %% [markdown]
# For single scattering albedo

# %%
pyAERO.GetDataAEROET('Sao_Paulo','2002-02-01','2005-02-01','SSA',temporal_type=False,inversion_type='ALM20')

# %% [markdown]
# enjoy!
